# %%
import viz_irregular as viz

ctx = viz.setup(min_ping_gap_sec=900, n_underway=300, n_stationary=300, seq_len=12)
model, vel_scale, meta = viz.load_checkpoint_model('checkpoints/irregular_batched.pt')

viz.evaluate(model, ctx.combined_val, vel_scale)
viz.per_horizon_errors(model, ctx.combined_val, vel_scale)
fig = viz.plot_grid(model, ctx.combined_val, vel_scale, ctx)
# Out:
# mesh: 5581 nodes, 16717 edges
# AIS: 26571570 records, 6640 vessels
# vessels: 480 train, 120 held-out
# held-out windows: 4865 across 96 vessels
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import viz_irregular as viz
#       3 ctx = viz.setup(min_ping_gap_sec=900, n_underway=300, n_stationary=300, seq_len=12)
# ----> 4 model, vel_scale, meta = viz.load_checkpoint_model('checkpoints/irregular_batched.pt')
#       6 viz.evaluate(model, ctx.combined_val, vel_scale)
#       7 viz.per_horizon_errors(model, ctx.combined_val, vel_scale)
#
# File /sfs/gpfs/tardis/home/jtb3sud/maritime-irregular/viz_irregular.py:144, in load_checkpoint_model(checkpoint_path, device)
#     141 """Loads a checkpoint, inferring architecture from the state dict.
#     142 Returns (model in eval mode, vel_scale, metadata)."""
# ...
